# %% [markdown]
# <h1 style="text-align:center;">Reporte de futuros y tasas</h1>

# %% [markdown]
# ## Tasas implicitas de Futuros

# %%
import pandas as pd
from datetime import date, timedelta
from futures_rfx import *
from bcra import *
from IPython.display import display, HTML

end = date.today()
start = end - timedelta(days=30)

df = get_futures(start,end)
TAMAR_SERIE = get_tamar_serie(start, end ,id_variable=44)
rates = get_implied_rates(df)

volume = df.pivot(index='dateTime',columns='symbol',values=['volume'])
volume.columns = volume.columns.droplevel(0)  # Drop the top level of the MultiIndex

openInterest = df.pivot(index='dateTime',columns='symbol',values=['openInterest'])
openInterest.columns = openInterest.columns.droplevel(0)  # Drop the top level of the MultiIndex

# %%
# Plot limits
last_futures_close = get_last_futures_close_fx_limits(df)
plot_limits(last_futures_close)
# Plot rates
plot_smooth(rates[rates < 100])
# Table display
rates_display = rates.copy()
rates_display = rates_display/100
rates_display.index = rates_display.index.strftime("%Y-%m-%d")
rates_display = rates_display.style.background_gradient(cmap="YlOrRd")
rates_display = rates_display.format("{:.1%}")
display(HTML(rates_display.to_html().replace('<table',
                                '<table style="font-size:10px"')))

plot_tamar_serie(TAMAR_SERIE, figsize=(15,5))
# Out:
# <style type="text/css">
# #T_c0540_row0_col0, #T_c0540_row0_col1, #T_c0540_row0_col2, #T_c0540_row0_col4, #T_c0540_row0_col5, #T_c0540_row13_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_c0540_row0_col3 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_c0540_row1_col0, #T_c0540_row9_col5 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_c0540_row1_col1, #T_c0540_row1_col5 {
#   background-color: #fec561;
#   color: #000000;
# }
# #T_c0540_row1_col2, #T_c0540_row13_col0 {
#   background-color: #fecb67;
#   color: #000000;
# }
# #T_c0540_row1_col3 {
#   background-color: #fea145;
#   color: #000000;
# }
# #T_c0540_row1_col4, #T_c0540_row2_col3 {
#   background-color: #feaf4b;
#   color: #000000;
# }
# #T_c0540_row2_col0 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_c0540_row2_col1, #T_c0540_row2_col5 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_c0540_row2_col2, #T_c0540_row8_col2 {
#   background-color: #feba55;
#   color: #000000;
# }
# #T_c0540_row2_col4 {
#   background-color: #feb852;
#   color: #000000;
# }
# #T_c0540_row3_col0 {
#   background-color: #d6111f;
#   color: #f1f1f1;
# }
# #T_c0540_row3_col1, #T_c0540_row5_col1, #T_c0540_row7_col1, #T_c0540_row10_col0, #T_c0540_row11_col1, #T_c0540_row15_col1, #T_c0540_row17_col0, #T_c0540_row17_col1, #T_c0540_row18_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_c0540_row3_col2 {
#   background-color: #b60026;
#   color: #f1f1f1;
# }
# #T_c0540_row3_col3 {
#   background-color: #e51e1d;
#   color: #f1f1f1;
# }
# #T_c0540_row3_col4 {
#   background-color: #da141e;
#   color: #f1f1f1;
# }
# #T_c0540_row3_col5 {
#   background-color: #e31a1c;
#   color: #f1f1f1;
# }
# #T_c0540_row4_col0 {
#   background-color: #f94828;
#   color: #f1f1f1;
# }
# #T_c0540_row4_col1 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_c0540_row4_col2, #T_c0540_row16_col5 {
#   background-color: #ec2c21;
#   color: #f1f1f1;
# }
# #T_c0540_row4_col3, #T_c0540_row12_col0 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_c0540_row4_col4 {
#   background-color: #fc592d;
#   color: #f1f1f1;
# }
# #T_c0540_row4_col5 {
#   background-color: #fc552c;
#   color: #f1f1f1;
# }
# #T_c0540_row5_col0, #T_c0540_row17_col3 {
#   background-color: #c50624;
#   color: #f1f1f1;
# }
# #T_c0540_row5_col2 {
#   background-color: #ac0026;
#   color: #f1f1f1;
# }
# #T_c0540_row5_col3 {
#   background-color: #e92720;
#   color: #f1f1f1;
# }
# #T_c0540_row5_col4, #T_c0540_row16_col4 {
#   background-color: #cf0c21;
#   color: #f1f1f1;
# }
# #T_c0540_row5_col5 {
#   background-color: #c10325;
#   color: #f1f1f1;
# }
# #T_c0540_row6_col0, #T_c0540_row6_col1, #T_c0540_row6_col2, #T_c0540_row6_col3, #T_c0540_row6_col4, #T_c0540_row6_col5 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_c0540_row7_col0, #T_c0540_row7_col5, #T_c0540_row14_col1 {
#   background-color: #fd7636;
#   color: #f1f1f1;
# }
# #T_c0540_row7_col2 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_c0540_row7_col3, #T_c0540_row11_col4 {
#   background-color: #fc5f2f;
#   color: #f1f1f1;
# }
# #T_c0540_row7_col4 {
#   background-color: #fc612f;
#   color: #f1f1f1;
# }
# #T_c0540_row8_col0 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_c0540_row8_col1 {
#   background-color: #fea948;
#   color: #000000;
# }
# #T_c0540_row8_col3, #T_c0540_row9_col0 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_c0540_row8_col4 {
#   background-color: #feb34d;
#   color: #000000;
# }
# #T_c0540_row8_col5 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_c0540_row9_col1, #T_c0540_row9_col4 {
#   background-color: #fec15d;
#   color: #000000;
# }
# #T_c0540_row9_col2 {
#   background-color: #fec05b;
#   color: #000000;
# }
# #T_c0540_row9_col3 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_c0540_row10_col1, #T_c0540_row10_col5, #T_c0540_row14_col2 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_c0540_row10_col2, #T_c0540_row14_col4 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_c0540_row10_col3 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_c0540_row10_col4 {
#   background-color: #fd8a3b;
#   color: #f1f1f1;
# }
# #T_c0540_row11_col0 {
#   background-color: #fc6330;
#   color: #f1f1f1;
# }
# #T_c0540_row11_col2, #T_c0540_row18_col5 {
#   background-color: #fd7836;
#   color: #f1f1f1;
# }
# #T_c0540_row11_col3 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_c0540_row11_col5 {
#   background-color: #fc6631;
#   color: #f1f1f1;
# }
# #T_c0540_row12_col1 {
#   background-color: #fd7234;
#   color: #f1f1f1;
# }
# #T_c0540_row12_col2, #T_c0540_row18_col2 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
# }
# #T_c0540_row12_col3 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_c0540_row12_col4, #T_c0540_row15_col2 {
#   background-color: #fc4f2a;
#   color: #f1f1f1;
# }
# #T_c0540_row12_col5, #T_c0540_row14_col0 {
#   background-color: #fd7435;
#   color: #f1f1f1;
# }
# #T_c0540_row13_col1 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_c0540_row13_col2 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_c0540_row13_col4 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_c0540_row13_col5 {
#   background-color: #fed36f;
#   color: #000000;
# }
# #T_c0540_row14_col3 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_c0540_row14_col5 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_c0540_row15_col0, #T_c0540_row18_col3 {
#   background-color: #ef3323;
#   color: #f1f1f1;
# }
# #T_c0540_row15_col3, #T_c0540_row19_col4 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_c0540_row15_col4 {
#   background-color: #eb2b21;
#   color: #f1f1f1;
# }
# #T_c0540_row15_col5 {
#   background-color: #f74327;
#   color: #f1f1f1;
# }
# #T_c0540_row16_col0 {
#   background-color: #f23924;
#   color: #f1f1f1;
# }
# #T_c0540_row16_col1 {
#   background-color: #ed2e21;
#   color: #f1f1f1;
# }
# #T_c0540_row16_col2 {
#   background-color: #f43e26;
#   color: #f1f1f1;
# }
# #T_c0540_row16_col3 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_c0540_row17_col2 {
#   background-color: #ee3122;
#   color: #f1f1f1;
# }
# #T_c0540_row17_col4 {
#   background-color: #cb0a22;
#   color: #f1f1f1;
# }
# #T_c0540_row17_col5 {
#   background-color: #e7231e;
#   color: #f1f1f1;
# }
# #T_c0540_row18_col0 {
#   background-color: #fd8038;
#   color: #f1f1f1;
# }
# #T_c0540_row18_col4 {
#   background-color: #f84628;
#   color: #f1f1f1;
# }
# #T_c0540_row19_col0 {
#   background-color: #fd8239;
#   color: #f1f1f1;
# }
# #T_c0540_row19_col1 {
#   background-color: #fd883b;
#   color: #f1f1f1;
# }
# #T_c0540_row19_col2 {
#   background-color: #fd933f;
#   color: #000000;
# }
# #T_c0540_row19_col3 {
#   background-color: #fd9c42;
#   color: #000000;
# }
# #T_c0540_row19_col5 {
#   background-color: #fd953f;
#   color: #000000;
# }
# </style>
# <table style="font-size:10px" id="T_c0540">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th id="T_c0540_level0_col0" class="col_heading level0 col0" >DLR012026</th>
#       <th id="T_c0540_level0_col1" class="col_heading level0 col1" >DLR022026</th>
#       <th id="T_c0540_level0_col2" class="col_heading level0 col2" >DLR052026</th>
#       <th id="T_c0540_level0_col3" class="col_heading level0 col3" >DLR102025</th>
#       <th id="T_c0540_level0_col4" class="col_heading level0 col4" >DLR112025</th>
#       <th id="T_c0540_level0_col5" class="col_heading level0 col5" >DLR122025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >dateTime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0540_level0_row0" class="row_heading level0 row0" >2025-09-22</th>
#       <td id="T_c0540_row0_col0" class="data row0 col0" >27.4%</td>
#       <td id="T_c0540_row0_col1" class="data row0 col1" >26.6%</td>
#       <td id="T_c0540_row0_col2" class="data row0 col2" >27.0%</td>
#       <td id="T_c0540_row0_col3" class="data row0 col3" >9.7%</td>
#       <td id="T_c0540_row0_col4" class="data row0 col4" >21.0%</td>
#       <td id="T_c0540_row0_col5" class="data row0 col5" >27.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c0540_level0_row1" class="row_heading level0 row1" >2025-09-23</th>
#       <td id="T_c0540_row1_col0" class="d

# %% [markdown]
# ## Interes Abierto y Volumen diario

# %%
plot_futures(data=volume, kind='bar', ylabel="Volume", title="Volume Over Time", legend_name = "Volume")
plot_futures(data=openInterest, kind='bar', ylabel="Open Interest", title="Open Interest Over Time", legend_name = "Open Interest")
